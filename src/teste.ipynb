# %%
from readData import Data
#from match import match

# %%
db = Data()

# %%
query="""SELECT p1.player_name, p1.birthday, p2.*
        FROM (SELECT * FROM Player WHERE player_api_id = 505942) AS p1
        LEFT JOIN Player_Attributes AS p2
        ON p1.player_api_id = p2.player_api_id"""
db.returnQuery(query=query)
# Out:
#           player_name             birthday  index  id  player_fifa_api_id  \
# 0  Aaron Appindangoye  1992-02-29 00:00:00      0   1              218353
# 1  Aaron Appindangoye  1992-02-29 00:00:00      1   2              218353
# 2  Aaron Appindangoye  1992-02-29 00:00:00      2   3              218353
# 3  Aaron Appindangoye  1992-02-29 00:00:00      3   4              218353
# 4  Aaron Appindangoye  1992-02-29 00:00:00      4   5              218353
#
#    player_api_id                 date  overall_rating  potential  \
# 0         505942  2016-02-18 00:00:00            67.0       71.0
# 1         505942  2015-11-19 00:00:00            67.0       71.0
# 2         505942  2015-09-21 00:00:00            62.0       66.0
# 3         505942  2015-03-20 00:00:00            61.0       65.0
# 4         505942  2007-02-22 00:00:00            61.0       65.0
#
#   preferred_foot  ... vision penalties  marking  standing_tackle  \
# ...

# %%
print(db.conn.cursor().execute("select name from sqlite_master where type = 'table';").fetchall())
# Out:
# [('sqlite_sequence',), ('Player_Attributes',), ('Player',), ('Match',), ('League',), ('Country',), ('Team',), ('Team_Attributes',)]

# %%
table_names = db.conn.execute("""select m.name from sqlite_master m where m.type = 'table' and exists 
    (select 1 from pragma_table_info(m.name) m1 where m1.name = 'date')""").fetchall()

# %%
db.conn.cursor().execute("""select m.name from sqlite_master m where m.type = 'table' and exists 
            (select 1 from pragma_table_info(m.name) m1 where m1.name = 'date')""").fetchall()
# Out:
# [('Player_Attributes',), ('Match',), ('Team_Attributes',)]

# %%
for i in range(0, len(table_names)):
    print(i)
# Out:
# 0
# 1
# 2

# %%
# Out:
# 'Team_Attributes'

# %%
db.conn.execute("select * from sqlite_sequence").fetchall()
# Out:
# [('Team', 103916),
#  ('Country', 51958),
#  ('League', 51958),
#  ('Match', 51958),
#  ('Player', 11075),
#  ('Player_Attributes', 183978),
#  ('Team_Attributes', 1458)]

# %%
import pandas as pd

# %%
tst = pd.read_sql("""select * from player_attributes limit 5""", db.conn)

# %%
tst["date"] = pd.to_datetime(tst["date"])

# %%
tst.to_sql()
# Out:
#    id  player_fifa_api_id  player_api_id       date  overall_rating  \
# 0   1              218353         505942 2016-02-18              67
# 1   2              218353         505942 2015-11-19              67
# 2   3              218353         505942 2015-09-21              62
# 3   4              218353         505942 2015-03-20              61
# 4   5              218353         505942 2007-02-22              61
#
#    potential preferred_foot attacking_work_rate defensive_work_rate  crossing  \
# 0         71          right              medium              medium        49
# 1         71          right              medium              medium        49
# 2         66          right              medium              medium        49
# 3         65          right              medium              medium        48
# 4         65          right              medium              medium        48
#
#    ...  vision  penalties  marking  standing_tackle  sliding_tackle  \
# ...

# %%
db.conn.execute("""select * from player""").fetchall()
# Out:
# [(1, 505942, 'Aaron Appindangoye', 218353, '1992-02-29 00:00:00', 182.88, 187),
#  (2, 155782, 'Aaron Cresswell', 189615, '1989-12-15 00:00:00', 170.18, 146),
#  (3, 162549, 'Aaron Doran', 186170, '1991-05-13 00:00:00', 170.18, 163),
#  (4, 30572, 'Aaron Galindo', 140161, '1982-05-08 00:00:00', 182.88, 198),
#  (5, 23780, 'Aaron Hughes', 17725, '1979-11-08 00:00:00', 182.88, 154),
#  (6, 27316, 'Aaron Hunt', 158138, '1986-09-04 00:00:00', 182.88, 161),
#  (7, 564793, 'Aaron Kuhl', 221280, '1996-01-30 00:00:00', 172.72, 146),
#  (8, 30895, 'Aaron Lennon', 152747, '1987-04-16 00:00:00', 165.1, 139),
#  (9, 528212, 'Aaron Lennox', 206592, '1993-02-19 00:00:00', 190.5, 181),
#  (10, 101042, 'Aaron Meijers', 188621, '1987-10-28 00:00:00', 175.26, 170),
#  (11, 23889, 'Aaron Mokoena', 47189, '1980-11-25 00:00:00', 182.88, 181),
#  (12, 231592, 'Aaron Mooy', 194958, '1990-09-15 00:00:00', 175.26, 150),
#  (13, 163222, 'Aaron Muirhead', 213568, '1990-08-30 00:00:00', 187.96, 168),
# ...

# %%
match(492473)
# Out:
# [None, None, None, None, None, None, None, None, None, None, None]
# KRC Genk
# Beerschot AC

# %%
query = """SELECT *
        FROM MATCH
        WHERE match_api_id == {matchId};"""
match = returnQuery(query=query.format(matchId=1992091)).iloc[0]

# %%
match["home_player_1"]
# Out:
# 42231

# %%
[match["home_player_{index}".format(index=i)] for i in range(1,12)]
# Out:
# [42231,
#  678384,
#  95220,
#  638592,
#  413155,
#  45780,
#  171229,
#  67333,
#  119839,
#  143790,
#  195215]

# %%
tst=returnQuery(table="League")

# %%
tst.
# Out:
#        id  country_id                      name
# 0       1           1    Belgium Jupiler League
# 1    1729        1729    England Premier League
# 2    4769        4769            France Ligue 1
# 3    7809        7809     Germany 1. Bundesliga
# 4   10257       10257             Italy Serie A
# 5   13274       13274    Netherlands Eredivisie
# 6   15722       15722        Poland Ekstraklasa
# 7   17642       17642  Portugal Liga ZON Sagres
# 8   19694       19694   Scotland Premier League
# 9   21518       21518           Spain LIGA BBVA
# 10  24558       24558  Switzerland Super League

# %%
globals()[tst][0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Matheus\Projetos ML\soccer_odds\src\teste.ipynb Célula: 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Matheus/Projetos%20ML/soccer_odds/src/teste.ipynb#Y100sZmlsZQ%3D%3D?line=0'>1</a> globals()[tst][0]
#
# TypeError: unhashable type: 'DataFrame'

# %%
queryTst = """select home_player_1
from match"""
returnQuery(query=queryTst)
# Out:
#        home_player_1
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 25974        42231.0
# 25975        33272.0
# 25976       157856.0
# 25977            NaN
# 25978       274787.0
#
# [25979 rows x 1 columns]

# %%
returnQuery(table="Player")
# Out:
#           id  player_api_id          player_name  player_fifa_api_id  \
# 0          1         505942   Aaron Appindangoye              218353
# 1          2         155782      Aaron Cresswell              189615
# 2          3         162549          Aaron Doran              186170
# 3          4          30572        Aaron Galindo              140161
# 4          5          23780         Aaron Hughes               17725
# ...      ...            ...                  ...                 ...
# 11055  11071          26357       Zoumana Camara                2488
# 11056  11072         111182         Zsolt Laczko              164680
# 11057  11073          36491            Zsolt Low              111191
# 11058  11074          35506  Zurab Khizanishvili               47058
# 11059  11075          39902   Zvjezdan Misimovic              102359
#
#                   birthday  height  weight
# 0      1992-02-29 00:00:00  182.88     187
# 1      1989-12-15 00:00:00  170.18     146
# ...

# %%
returnQuery(table="Match")
# Out:
#           id  country_id  league_id     season  stage                 date  \
# 0          1           1          1  2008/2009      1  2008-08-17 00:00:00
# 1          2           1          1  2008/2009      1  2008-08-16 00:00:00
# 2          3           1          1  2008/2009      1  2008-08-16 00:00:00
# 3          4           1          1  2008/2009      1  2008-08-17 00:00:00
# 4          5           1          1  2008/2009      1  2008-08-16 00:00:00
# ...      ...         ...        ...        ...    ...                  ...
# 25974  25975       24558      24558  2015/2016      9  2015-09-22 00:00:00
# 25975  25976       24558      24558  2015/2016      9  2015-09-23 00:00:00
# 25976  25977       24558      24558  2015/2016      9  2015-09-23 00:00:00
# 25977  25978       24558      24558  2015/2016      9  2015-09-22 00:00:00
# 25978  25979       24558      24558  2015/2016      9  2015-09-23 00:00:00
#
# ...

# %%
returnQuery(table="Team")
# Out:
#         id  team_api_id  team_fifa_api_id      team_long_name team_short_name
# 0        1         9987             673.0            KRC Genk             GEN
# 1        2         9993             675.0        Beerschot AC             BAC
# 2        3        10000           15005.0    SV Zulte-Waregem             ZUL
# 3        4         9994            2007.0    Sporting Lokeren             LOK
# 4        5         9984            1750.0   KSV Cercle Brugge             CEB
# ..     ...          ...               ...                 ...             ...
# 294  49479        10190             898.0       FC St. Gallen             GAL
# 295  49837        10191            1715.0             FC Thun             THU
# 296  50201         9777             324.0         Servette FC             SER
# 297  50204         7730            1862.0  FC Lausanne-Sports             LAU
# 298  51606         7896               NaN              Lugano             LUG
#
# [299 rows x 5 columns]

# %%
returnQuery("player_attributes")
# Out:
#             id  player_fifa_api_id  player_api_id                 date  \
# 0            1              218353         505942  2016-02-18 00:00:00
# 1            2              218353         505942  2015-11-19 00:00:00
# 2            3              218353         505942  2015-09-21 00:00:00
# 3            4              218353         505942  2015-03-20 00:00:00
# 4            5              218353         505942  2007-02-22 00:00:00
# ...        ...                 ...            ...                  ...
# 183973  183974              102359          39902  2009-08-30 00:00:00
# 183974  183975              102359          39902  2009-02-22 00:00:00
# 183975  183976              102359          39902  2008-08-30 00:00:00
# 183976  183977              102359          39902  2007-08-30 00:00:00
# 183977  183978              102359          39902  2007-02-22 00:00:00
#
#         overall_rating  potential preferred_foot attacking_work_rate  \
# ...

# %%
import sqlite3
conn = sqlite3.connect("D:\Matheus\Projetos ML\soccer_odds\data\database.sqlite")

# %%
import pandas as pd

# %%
pd.read_sql("""SELECT p1.player_name, p1.birthday, p2.*
        FROM Player AS p1
        LEFT JOIN Player_Attributes AS p2
        ON p1.player_api_id = p2.player_api_id
        WHERE p1.player_api_id = 505942""", conn)
# Out:
#           player_name             birthday  id  player_fifa_api_id  \
# 0  Aaron Appindangoye  1992-02-29 00:00:00   1              218353
# 1  Aaron Appindangoye  1992-02-29 00:00:00   2              218353
# 2  Aaron Appindangoye  1992-02-29 00:00:00   3              218353
# 3  Aaron Appindangoye  1992-02-29 00:00:00   4              218353
# 4  Aaron Appindangoye  1992-02-29 00:00:00   5              218353
#
#    player_api_id                 date  overall_rating  potential  \
# 0         505942  2016-02-18 00:00:00              67         71
# 1         505942  2015-11-19 00:00:00              67         71
# 2         505942  2015-09-21 00:00:00              62         66
# 3         505942  2015-03-20 00:00:00              61         65
# 4         505942  2007-02-22 00:00:00              61         65
#
#   preferred_foot attacking_work_rate  ... vision  penalties  marking  \
# 0          right              medium  ...     54         48       65
# ...

# %%
returnQuery(query="""SELECT p1.player_name, p1.birthday, p2.*
        FROM Player AS p1
        LEFT JOIN Player_Attributes AS p2
        ON p1.player_api_id = p2.player_api_id
        WHERE p1.player_api_id = 505942""")
# Out:
#           player_name             birthday  id  player_fifa_api_id  \
# 0  Aaron Appindangoye  1992-02-29 00:00:00   1              218353
# 1  Aaron Appindangoye  1992-02-29 00:00:00   2              218353
# 2  Aaron Appindangoye  1992-02-29 00:00:00   3              218353
# 3  Aaron Appindangoye  1992-02-29 00:00:00   4              218353
# 4  Aaron Appindangoye  1992-02-29 00:00:00   5              218353
#
#    player_api_id                 date  overall_rating  potential  \
# 0         505942  2016-02-18 00:00:00              67         71
# 1         505942  2015-11-19 00:00:00              67         71
# 2         505942  2015-09-21 00:00:00              62         66
# 3         505942  2015-03-20 00:00:00              61         65
# 4         505942  2007-02-22 00:00:00              61         65
#
#   preferred_foot attacking_work_rate  ... vision  penalties  marking  \
# 0          right              medium  ...     54         48       65
# ...

# %%
returnQuery(query="""SELECT *
        FROM Player_Attributes
        WHERE player_api_id = 505942""")
# Out:
#    id  player_fifa_api_id  player_api_id                 date  overall_rating  \
# 0   1              218353         505942  2016-02-18 00:00:00              67
# 1   2              218353         505942  2015-11-19 00:00:00              67
# 2   3              218353         505942  2015-09-21 00:00:00              62
# 3   4              218353         505942  2015-03-20 00:00:00              61
# 4   5              218353         505942  2007-02-22 00:00:00              61
#
#    potential preferred_foot attacking_work_rate defensive_work_rate  crossing  \
# 0         71          right              medium              medium        49
# 1         71          right              medium              medium        49
# 2         66          right              medium              medium        49
# 3         65          right              medium              medium        48
# 4         65          right              medium              medium        48
#
# ...

# %%
query="""SELECT p1.player_name, p1.birthday, p2.*
        FROM Player AS p1
        LEFT JOIN Player_Attributes AS p2
        ON p1.player_api_id = p2.player_api_id
        WHERE p1.player_api_id = {name}
        AND date > {date};"""
query=query.format(name=505942, date="2015-03-20")

# %%
query
# Out:
# 'SELECT p1.player_name, p1.birthday, p2.*\n        FROM Player AS p1\n        LEFT JOIN Player_Attributes AS p2\n        ON p1.player_api_id = p2.player_api_id\n        WHERE p1.player_api_id = 505942\n        AND date > 2015-03-20;'

# %%
tst = returnQuery(query=query)

# %%
import pandas as pd

# %%
pd.to_datetime(tst["date"])
# Out:
# 0   2016-02-18
# 1   2015-11-19
# 2   2015-09-21
# 3   2015-03-20
# 4   2007-02-22
# Name: date, dtype: datetime64[ns]

# %%
query="""SELECT p1.player_name, p1.birthday, p2.*
        FROM Player AS p1
        LEFT JOIN Player_Attributes AS p2
        ON p1.player_api_id = p2.player_api_id
        WHERE p1.player_api_id = {name}
        AND TO_DATE(date) > {date};"""
query=query.format(name=505942, date="2015-03-20")

# %%
import sqlite3

# %%
database = os.path.join("D:\Matheus\Projetos ML\soccer_odds\data", "database.sqlite")
conn = sqlite3.connect(database)
tst = pd.read_sql_query("""SELECT * FROM PLAYER_ATTRIBUTES""", conn)

# %%
conn.cursor().execute("SELECT name FROM sqlite_master WHERE type='table';")

# %%
tst.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\Matheus\Projetos ML\soccer_odds\src\teste.ipynb Célula: 27 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Matheus/Projetos%20ML/soccer_odds/src/teste.ipynb#Y101sZmlsZQ%3D%3D?line=0'>1</a> tst.name
#
# File d:\Matheus\anaconda3\envs\soccerOdds\lib\site-packages\pandas\core\generic.py:5907, in NDFrame.__getattr__(self, name)
#    5900 if (
#    5901     name not in self._internal_names_set
#    5902     and name not in self._metadata
#    5903     and name not in self._accessors
#    5904     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5905 ):
#    5906     return self[name]
# -> 5907 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'name'

# %%
conn.cursor()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Matheus\Projetos ML\soccer_odds\src\teste.ipynb Célula: 23 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Matheus/Projetos%20ML/soccer_odds/src/teste.ipynb#X63sZmlsZQ%3D%3D?line=0'>1</a> conn.cursor().execute()
#
# TypeError: execute expected at least 1 argument, got 0

# %%
returnQuery(query="Select *")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File d:\Matheus\anaconda3\envs\soccerOdds\lib\site-packages\pandas\io\sql.py:2019, in SQLiteDatabase.execute(self, *args, **kwargs)
#    2018 try:
# -> 2019     cur.execute(*args, **kwargs)
#    2020     return cur
#
# OperationalError: no tables specified
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# d:\Matheus\Projetos ML\soccer_odds\src\teste.ipynb Célula: 22 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Matheus/Projetos%20ML/soccer_odds/src/teste.ipynb#X61sZmlsZQ%3D%3D?line=0'>1</a> returnQuery(query="Select *")
#
# File d:\Matheus\Projetos ML\soccer_odds\src\readData.py:23, in returnQuery(table, query)
#      19     query=query
#      21 conn = sqlite3.connect(database)
# ...
