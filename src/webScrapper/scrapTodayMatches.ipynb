# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from scrapper import scrapper

# %%
myPath = "D:/chromedriver_win32/chromedriver.exe"
scrapper = scrapper(myPath)

# %%
df = scrapper.getMatchesToday()

# %%
df.head()
# Out:
#        homeTeam             awayTeam homeOdds drawOdds awayOdds  \
# 0       Sevilla        Real Sociedad     2.50     3.30     2.88
# 1    UD Almería            Getafe CF     2.05     3.20     4.00
# 2      Espanyol           Villarreal     2.80     3.30     2.55
# 3  RCD Mallorca      Atlético Madrid     4.00     2.87     2.15
# 4    1. FC Köln  Bayer 04 Leverkusen     3.00     3.60     2.25
#
#          homePlayer1        homePlayer2     homePlayer3      homePlayer4  \
# 0               Bono        Jesús Navas  Tanguy Nianzou      Karim Rekik
# 1  Fernando Martínez  Houboulang Mendes           Chumi      Srđan Babić
# 2   Benjamin Lecomte          Óscar Gil     Sergi Gómez  Fernando Calero
# 3   Predrag Rajković        G. González      M. Valjent        A. Raíllo
# 4     Marvin Schwäbe      Benno Schmitz    Nikola Soldo      Luca Kilian
#
#        homePlayer5  ...    awayPlayer2       awayPlayer3     awayPlayer4  \
# ...
