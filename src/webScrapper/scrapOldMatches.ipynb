# %%
import pandas as pd
import os
import sys
from scrapper import scrapper
from datetime import date

dataFolder = os.path.join(os.path.dirname(os.path.dirname(os.path.abspath(os.path.dirname('')))), 'data\\')
sys.path.append(dataFolder)

# %% [markdown]
# Scrapper

# %%
teste = Scrapper()
df=teste.get_matches(start=date(2022,9,2), end=date(2022,11,15))
# Out:
# https://fbref.com/en/matches/2022-09-02
# https://fbref.com/en/matches/2022-09-03
# https://fbref.com/en/matches/2022-09-04
# https://fbref.com/en/matches/2022-09-05
# https://fbref.com/en/matches/2022-09-06
# https://fbref.com/en/matches/2022-09-07
# https://fbref.com/en/matches/2022-09-08
# https://fbref.com/en/matches/2022-09-09
# https://fbref.com/en/matches/2022-09-10
# https://fbref.com/en/matches/2022-09-11
# https://fbref.com/en/matches/2022-09-12
# https://fbref.com/en/matches/2022-09-13
# https://fbref.com/en/matches/2022-09-14
# https://fbref.com/en/matches/2022-09-15
# https://fbref.com/en/matches/2022-09-16
# https://fbref.com/en/matches/2022-09-17
# https://fbref.com/en/matches/2022-09-18
# https://fbref.com/en/matches/2022-09-19
# https://fbref.com/en/matches/2022-09-20
# https://fbref.com/en/matches/2022-09-21
# https://fbref.com/en/matches/2022-09-22
# https://fbref.com/en/matches/2022-09-23
# https://fbref.com/en/matches/2022-09-24
# https://fbref.com/en/matches/2022-09-25
# https://fbref.com/en/matches/2022-09-26
# https://fbref.com/en/matches/2022-09-27
# https://fbref.com/en/matches/2022-09-28
# https://fbref.com/en/matches/2022-09-29
# https://fbref.com/en/matches/2022-09-30
# https://fbref.com/en/matches/2022-10-01
# https://fbref.com/en/matches/2022-10-02
# https://fbref.com/en/matches/2022-10-03
# https://fbref.com/en/matches/2022-10-04
# https://fbref.com/en/matches/2022-10-05
# https://fbref.com/en/matches/2022-10-06
# https://fbref.com/en/matches/2022-10-07
# https://fbref.com/en/matches/2022-10-08
# https://fbref.com/en/matches/2022-10-09
# https://fbref.com/en/matches/2022-10-10
# https://fbref.com/en/matches/2022-10-11
# https://fbref.com/en/matches/2022-10-12
# https://fbref.com/en/matches/2022-10-13
# https://fbref.com/en/matches/2022-10-14
# https://fbref.com/en/matches/2022-10-15
# https://fbref.com/en/matches/2022-10-16
# https://fbref.com/en/matches/2022-10-17
# https://fbref.com/en/matches/2022-10-18
# https://fbref.com/en/matches/2022-10-19
# https://fbref.com/en/matches/2022-10-20
# https://fbref.com/en/matches/2022-10-21
# https://fbref.com/en/matches/2022-10-22
# https://fbref.com/en/matches/2022-10-23
# https://fbref.com/en/matches/2022-10-24
# https://fbref.com/en/matches/2022-10-25
# https://fbref.com/en/matches/2022-10-26
# https://fbref.com/en/matches/2022-10-27
# https://fbref.com/en/matches/2022-10-28
# https://fbref.com/en/matches/2022-10-29
# https://fbref.com/en/matches/2022-10-30
# https://fbref.com/en/matches/2022-10-31
# https://fbref.com/en/matches/2022-11-01
# https://fbref.com/en/matches/2022-11-02
# https://fbref.com/en/matches/2022-11-03
# https://fbref.com/en/matches/2022-11-04
# https://fbref.com/en/matches/2022-11-05
# https://fbref.com/en/matches/2022-11-06
# https://fbref.com/en/matches/2022-11-07
# https://fbref.com/en/matches/2022-11-08
# https://fbref.com/en/matches/2022-11-09
# https://fbref.com/en/matches/2022-11-10
# https://fbref.com/en/matches/2022-11-11
# https://fbref.com/en/matches/2022-11-12
# https://fbref.com/en/matches/2022-11-13
# https://fbref.com/en/matches/2022-11-14

# %%
pd.read_pickle(os.path.join(dataFolder,"checkPoint.pkl")).tail(5)
# Out:
#                homePlayer1     homePlayer2    homePlayer3       homePlayer4  \
# 496  Leonardo César Jardim     Tiago Djaló     José Fonte    Jonathan Bamba
# 497         Steve Mandanda       Joe Rodon  Arthur Theate    Martin Terrier
# 498              Pau López     Eric Bailly   Samuel Gigot  Mattéo Guendouzi
# 499            Brice Samba  Deiver Machado    Kevin Danso    Florian Sotoca
# 500             Danny Ward    James Justin    Jonny Evans     Harvey Barnes
#
#              homePlayer5         homePlayer6          homePlayer7  \
# 496       Jonathan David        Yusuf Yazıcı       Bafodé Diakité
# 497  Baptiste Santamaria  Kamaldeen Sulemana  Benjamin Bourigeaud
# 498      Jonathan Clauss       Dimitri Payet     Valentin Rongier
# 499        Łukasz Poręba      Facundo Medina          Jimmy Cabot
# 500      Youri Tielemans         Jamie Vardy       James Maddison
#
#                 homePlayer8     homePlayer9     homePlayer10  ...  \
# 496             Angel Gomes  Benjamin André    Edon Zhegrova  ...
# 497            Flavien Tait     Lovro Majer  Lorenz Assignon  ...
# 498              Pape Gueye    Nuno Tavares   Alexis Sánchez  ...
# 499  David Pereira da Costa     Wesley Saïd  Jonathan Gradit  ...
# 500   Kiernan Dewsbury-Hall   Wilfred Ndidi      Luke Thomas  ...
#
#     awayThrowIns homeLongBalls awayLongBalls        homeTeam        awayTeam  \
# 496           14            54            65           Lille            Nice
# 497           23            64            91          Rennes           Brest
# 498           17            45            55       Marseille   Clermont Foot
# 499           19            44            36            Lens         Lorient
# 500           24            64            82  Leicester City  Manchester Utd
#
#     scoreHome scoreAway homeXG awayXG        date
# 496         1         2    0.9    1.6  2022-08-31
# 497         3         1    1.5    0.5  2022-08-31
# 498         1         0    2.5    0.1  2022-08-31
# 499         5         2    3.0    1.1  2022-08-31
# 500         0         1    0.7    1.5  2022-09-01
#
# [5 rows x 57 columns]

# %%
pd.read_pickle(os.path.join(dataFolder,"matchesDataset.pkl")).tail(5)
# Out:
#                homePlayer1     homePlayer2    homePlayer3       homePlayer4  \
# 496  Leonardo César Jardim     Tiago Djaló     José Fonte    Jonathan Bamba
# 497         Steve Mandanda       Joe Rodon  Arthur Theate    Martin Terrier
# 498              Pau López     Eric Bailly   Samuel Gigot  Mattéo Guendouzi
# 499            Brice Samba  Deiver Machado    Kevin Danso    Florian Sotoca
# 500             Danny Ward    James Justin    Jonny Evans     Harvey Barnes
#
#              homePlayer5         homePlayer6          homePlayer7  \
# 496       Jonathan David        Yusuf Yazıcı       Bafodé Diakité
# 497  Baptiste Santamaria  Kamaldeen Sulemana  Benjamin Bourigeaud
# 498      Jonathan Clauss       Dimitri Payet     Valentin Rongier
# 499        Łukasz Poręba      Facundo Medina          Jimmy Cabot
# 500      Youri Tielemans         Jamie Vardy       James Maddison
#
#                 homePlayer8     homePlayer9     homePlayer10  ...  \
# 496             Angel Gomes  Benjamin André    Edon Zhegrova  ...
# 497            Flavien Tait     Lovro Majer  Lorenz Assignon  ...
# 498              Pape Gueye    Nuno Tavares   Alexis Sánchez  ...
# 499  David Pereira da Costa     Wesley Saïd  Jonathan Gradit  ...
# 500   Kiernan Dewsbury-Hall   Wilfred Ndidi      Luke Thomas  ...
#
#     awayThrowIns homeLongBalls awayLongBalls        homeTeam        awayTeam  \
# 496         14.0          54.0          65.0           Lille            Nice
# 497         23.0          64.0          91.0          Rennes           Brest
# 498         17.0          45.0          55.0       Marseille   Clermont Foot
# 499         19.0          44.0          36.0            Lens         Lorient
# 500         24.0          64.0          82.0  Leicester City  Manchester Utd
#
#     scoreHome scoreAway homeXG awayXG        date
# 496       1.0       2.0    0.9    1.6  2022-08-31
# 497       3.0       1.0    1.5    0.5  2022-08-31
# 498       1.0       0.0    2.5    0.1  2022-08-31
# 499       5.0       2.0    3.0    1.1  2022-08-31
# 500       0.0       1.0    0.7    1.5  2022-09-01
#
# [5 rows x 57 columns]

# %% [markdown]
# Recovering scrapper backup

# %%
oldRunsDf = pd.read_pickle(os.path.join(dataFolder,"matchesDataset.pkl"))
lastRunBackup = pd.read_pickle(os.path.join(dataFolder,"checkPoint.pkl"))
dfNew = pd.concat([oldRunsDf, lastRunBackup], axis=0)
dfNew.to_pickle(path=os.path.join(dataFolder,"matchesDataset.pkl"))

# %%
dfNew.to_pickle(path=os.path.join(dataFolder,"matchesDataset.pkl"))

# %%
pd.read_pickle(os.path.join(dataFolder,"matchesDataset.pkl"))
# Out:
#            homePlayer1         homePlayer2          homePlayer3  \
# 0               Adrián     Aaron Cresswell        James Tomkins
# 1          Declan Rudd      Russell Martin    Sébastien Bassong
# 2         David de Gea          Phil Jones            Juan Mata
# 3            Petr Čech     Per Mertesacker    Laurent Koscielny
# 4          Boaz Myhill       Claudio Yacob          Jonny Evans
# ...                ...                 ...                  ...
# 10002      Jonas Omlin      Arnaud Souquet  Christopher Jullien
# 10003      Marco Bizot  Jean-Kevin Duverne      Lilian Brassier
# 10004     Alban Lafont      Andrei Girotto     Pedro Chirivella
# 10005        Matz Sels   Jean-Eudes Aholou        Kévin Gameiro
# 10006  Alexander Nübel   Guillermo Maripán       Mohamed Camara
#
#               homePlayer4        homePlayer5             homePlayer6  \
# 0        Cheikhou Kouyaté       Andy Carroll          Manuel Lanzini
# 1            Jonny Howson  Dieumerci Mbokani            Robbie Brady
# 2            Wayne Rooney    Anthony Martial          Chris Smalling
# 3              Mesut Özil     Olivier Giroud            Theo Walcott
# 4          James Morrison      Craig Gardner             Chris Brunt
# ...                   ...                ...                     ...
# 10002     Stephy Mavididi      Téji Savanier            Jordan Ferri
# 10003  Brendan Chardonnet     Franck Honorat     Romain Del Castillo
# 10004      Evann Guessand       Ludovic Blas          Moussa Sissoko
# 10005    Adrien Thomasson    Dimitri Liénard  Jean-Ricner Bellegarde
# 10006   Benoît Badiashile        Axel Disasi       Wissam Ben Yedder
#
#                         homePlayer7        homePlayer8           homePlayer9  \
# 0                    Enner Valencia         Mark Noble         James Collins
# 1                      Wes Hoolahan     Nathan Redmond          Ryan Bennett
# 2                       Daley Blind       Ashley Young         Ander Herrera
# 3           Alex Oxlade-Chamberlain       Aaron Ramsey         Nacho Monreal
# 4                    Rickie Lambert     Gareth McAuley       Darren Fletcher
# ...                             ...                ...                   ...
# 10002                 Maxime Estève          Léo Leroy        Sepe Elye Wahi
# 10003                 Islam Slimani  Pierre Lees-Melou  Mathias Pereira Lage
# 10004      Jean-Charles Castelletto  Sébastien Corchia           Moses Simon
# 10005         Ronaël Pierre-Gabriel     Gerzino Nyamsi    Maxime Le Marchand
# 10006  Caio Henrique Oliveira Silva  Aleksandr Golovin       Youssouf Fofana
#
#               homePlayer10  ... awayThrowIns homeLongBalls awayLongBalls  \
# 0           Angelo Ogbonna  ...          NaN           NaN           NaN
# 1         Alexander Tettey  ...          NaN           NaN           NaN
# 2      Morgan Schneiderlin  ...          NaN           NaN           NaN
# 3          Mathieu Flamini  ...          NaN           NaN           NaN
# 4             Craig Dawson  ...          NaN           NaN           NaN
# ...                    ...  ...          ...           ...           ...
# 10002        Nicolas Cozza  ...         31.0          81.0          70.0
# 10003         Mahdi Camara  ...         13.0          57.0          69.0
# 10004       Quentin Merlin  ...         17.0          73.0          84.0
# 10005      Alexander Djiku  ...         23.0          77.0          56.0
# 10006        Krepin Diatta  ...         12.0          62.0          60.0
#
#              homeTeam       awayTeam scoreHome scoreAway homeXG awayXG  \
# 0            West Ham      Liverpool       2.0       0.0    NaN    NaN
# 1        Norwich City    Southampton       1.0       0.0    NaN    NaN
# 2      Manchester Utd   Swansea City       2.0       1.0    NaN    NaN
# 3             Arsenal  Newcastle Utd       1.0       0.0    NaN    NaN
# 4           West Brom     Stoke City       2.0       1.0    NaN    NaN
# ...               ...            ...       ...       ...    ...    ...
# 10002     Montpellier          Reims       1.0       1.0    1.7    2.1
# 10003           Brest         Troyes       2.0       1.0    2.4    1.0
# 10004          Nantes        Ajaccio       2.0       2.0    1.1    2.5
# 10005      Strasbourg        Lorient       1.0       1.0    2.3    0.5
# 10006          Monaco      Marseille       2.0       3.0    2.0    1.9
#
#              date
# 0      2016-01-02
# 1      2016-01-02
# 2      2016-01-02
# 3      2016-01-02
# 4      2016-01-02
# ...           ...
# 10002  2022-11-13
# 10003  2022-11-13
# 10004  2022-11-13
# 10005  2022-11-13
# 10006  2022-11-13
#
# [10007 rows x 57 columns]
